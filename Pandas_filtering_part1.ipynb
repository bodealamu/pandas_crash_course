# %%
import pandas as pd

# %%
df = pd.read_csv('gapminder_2007.csv')

# %%
df.sample()
# Out:
#     Unnamed: 0.1  Unnamed: 0      country continent  year  lifeExp       pop  \
# 70           851         851  Korea, Rep.      Asia  2007   78.623  49044790
#
#       gdpPercap iso_alpha  iso_num
# 70  23348.13973       KOR      410

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'country', 'continent', 'year', 'lifeExp',
#        'pop', 'gdpPercap', 'iso_alpha', 'iso_num'],
#       dtype='object')

# %%
df =df.loc[:,['country', 'continent', 'year', 'lifeExp','pop', 'gdpPercap', 'iso_alpha', 'iso_num']]

# %%
df.sample()
# Out:
#         country continent  year  lifeExp      pop    gdpPercap iso_alpha  \
# 28  Congo, Rep.    Africa  2007   55.322  3800610  3632.557798       COG
#
#     iso_num
# 28      178

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    142 non-null    object
#  1   continent  142 non-null    object
#  2   year       142 non-null    int64
#  3   lifeExp    142 non-null    float64
#  4   pop        142 non-null    int64
#  5   gdpPercap  142 non-null    float64
#  6   iso_alpha  142 non-null    object
#  7   iso_num    142 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 9.0+ KB

# %%
df.describe()
# Out:
#          year     lifeExp           pop     gdpPercap     iso_num
# count   142.0  142.000000  1.420000e+02    142.000000  142.000000
# mean   2007.0   67.007423  4.402122e+07  11680.071820  425.880282
# std       0.0   12.073021  1.476214e+08  12859.937337  249.111541
# min    2007.0   39.613000  1.995790e+05    277.551859    4.000000
# 25%    2007.0   57.160250  4.508034e+06   1624.842248  209.500000
# 50%    2007.0   71.935500  1.051753e+07   6124.371109  410.000000
# 75%    2007.0   76.413250  3.121004e+07  18008.835640  636.000000
# max    2007.0   82.603000  1.318683e+09  49357.190170  894.000000

# %% [markdown]
# ## Find the country where life exp is less than 40 years old

# %%
# df[]

# %%
df['lifeExp'] < 40
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# Name: lifeExp, Length: 142, dtype: bool

# %%
df[df['lifeExp'] < 40]
# Out:
#        country continent  year  lifeExp      pop    gdpPercap iso_alpha  \
# 121  Swaziland    Africa  2007   39.613  1133066  4513.480643       SWZ
#
#      iso_num
# 121      748

# %%
df[df['lifeExp'] <= 40]
# Out:
#        country continent  year  lifeExp      pop    gdpPercap iso_alpha  \
# 121  Swaziland    Africa  2007   39.613  1133066  4513.480643       SWZ
#
#      iso_num
# 121      748

# %% [markdown]
# ## Find the country where life exp is more than 80 years old

# %%
df[df.lifeExp > 80]
# Out:
#               country continent  year  lifeExp        pop    gdpPercap  \
# 5           Australia   Oceania  2007   81.235   20434176  34435.36744
# 20             Canada  Americas  2007   80.653   33390141  36319.23501
# 44             France    Europe  2007   80.657   61083916  30470.01670
# 55   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 57            Iceland    Europe  2007   81.757     301931  36180.78919
# 63             Israel      Asia  2007   80.745    6426679  25523.27710
# 64              Italy    Europe  2007   80.546   58147733  28569.71970
# 66              Japan      Asia  2007   82.603  127467972  31656.06806
# 91        New Zealand   Oceania  2007   80.204    4115771  25185.00911
# 95             Norway    Europe  2007   80.196    4627926  49357.19017
# 118             Spain    Europe  2007   80.941   40448191  28821.06370
# 122            Sweden    Europe  2007   80.884    9031088  33859.74835
# ...

# %%
df[df.lifeExp >= 80]
# Out:
#               country continent  year  lifeExp        pop    gdpPercap  \
# 5           Australia   Oceania  2007   81.235   20434176  34435.36744
# 20             Canada  Americas  2007   80.653   33390141  36319.23501
# 44             France    Europe  2007   80.657   61083916  30470.01670
# 55   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 57            Iceland    Europe  2007   81.757     301931  36180.78919
# 63             Israel      Asia  2007   80.745    6426679  25523.27710
# 64              Italy    Europe  2007   80.546   58147733  28569.71970
# 66              Japan      Asia  2007   82.603  127467972  31656.06806
# 91        New Zealand   Oceania  2007   80.204    4115771  25185.00911
# 95             Norway    Europe  2007   80.196    4627926  49357.19017
# 118             Spain    Europe  2007   80.941   40448191  28821.06370
# 122            Sweden    Europe  2007   80.884    9031088  33859.74835
# ...

# %%
df[df.lifeExp >= 90]
# Out:
# Empty DataFrame
# Columns: [country, continent, year, lifeExp, pop, gdpPercap, iso_alpha, iso_num]
# Index: []

# %% [markdown]
# ## Find rows of data where continent is Africa

# %%
df['continent'] == 'Africa'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140     True
# 141     True
# Name: continent, Length: 142, dtype: bool

# %%
 df[df['continent'] == 'Africa']
# Out:
#                       country continent  year  lifeExp        pop  \
# 2                     Algeria    Africa  2007   72.301   33333216
# 3                      Angola    Africa  2007   42.731   12420476
# 10                      Benin    Africa  2007   56.728    8078314
# 13                   Botswana    Africa  2007   50.728    1639131
# 16               Burkina Faso    Africa  2007   52.295   14326203
# 17                    Burundi    Africa  2007   49.580    8390505
# 19                   Cameroon    Africa  2007   50.430   17696293
# 21   Central African Republic    Africa  2007   44.741    4369038
# 22                       Chad    Africa  2007   50.651   10238807
# 26                    Comoros    Africa  2007   65.152     710960
# 27           Congo, Dem. Rep.    Africa  2007   46.462   64606759
# 28                Congo, Rep.    Africa  2007   55.322    3800610
# 30              Cote d'Ivoire    Africa  2007   48.328   18013409
# ...

# %%
 df[df['continent'].isin(['Africa'])]
# Out:
#                       country continent  year  lifeExp        pop  \
# 2                     Algeria    Africa  2007   72.301   33333216
# 3                      Angola    Africa  2007   42.731   12420476
# 10                      Benin    Africa  2007   56.728    8078314
# 13                   Botswana    Africa  2007   50.728    1639131
# 16               Burkina Faso    Africa  2007   52.295   14326203
# 17                    Burundi    Africa  2007   49.580    8390505
# 19                   Cameroon    Africa  2007   50.430   17696293
# 21   Central African Republic    Africa  2007   44.741    4369038
# 22                       Chad    Africa  2007   50.651   10238807
# 26                    Comoros    Africa  2007   65.152     710960
# 27           Congo, Dem. Rep.    Africa  2007   46.462   64606759
# 28                Congo, Rep.    Africa  2007   55.322    3800610
# 30              Cote d'Ivoire    Africa  2007   48.328   18013409
# ...

# %%
# df[(df['continent'] == 'Africa') | (df['lifeExp'] < 40)]

# %%
(df['continent'] == 'Africa')
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140     True
# 141     True
# Name: continent, Length: 142, dtype: bool

# %%
(df['lifeExp'] < 40)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# Name: lifeExp, Length: 142, dtype: bool

# %%
df[(df['continent'] == 'Africa') & (df['lifeExp'] < 40)]
# Out:
#        country continent  year  lifeExp      pop    gdpPercap iso_alpha  \
# 121  Swaziland    Africa  2007   39.613  1133066  4513.480643       SWZ
#
#      iso_num
# 121      748
