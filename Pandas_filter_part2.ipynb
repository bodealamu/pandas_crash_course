# %%
import pandas as pd

# %%
df = pd.read_csv('gapminder_2007.csv')

# %%
df =df.loc[:,['country', 'continent', 'year', 'lifeExp','pop', 'gdpPercap', 'iso_alpha', 'iso_num']]

# %%
df.sample(4)
# Out:
#          country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 85       Morocco    Africa  2007   71.164  33757175   3820.175230       MAR
# 135      Uruguay  Americas  2007   76.384   3447496  10611.462990       URY
# 103     Portugal    Europe  2007   78.098  10642836  20509.647770       PRT
# 101  Philippines      Asia  2007   71.688  91077287   3190.481016       PHL
#
#      iso_num
# 85       504
# 135      858
# 103      620
# 101      608

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='object')

# %% [markdown]
# ## What if you want to find countries where life exp is greater than 50 AND country is from Africa?

# %%
True and False # What is the 'and' command in pandas?
# Out:
# False

# %%
(df['continent']=='Africa')
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140     True
# 141     True
# Name: continent, Length: 142, dtype: bool

# %%
(df['lifeExp']>50)
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 137     True
# 138     True
# 139     True
# 140    False
# 141    False
# Name: lifeExp, Length: 142, dtype: bool

# %%
df[(df['continent']=='Africa') & (df['lifeExp']>50)]
# Out:
#                    country continent  year  lifeExp       pop     gdpPercap  \
# 2                  Algeria    Africa  2007   72.301  33333216   6223.367465
# 10                   Benin    Africa  2007   56.728   8078314   1441.284873
# 13                Botswana    Africa  2007   50.728   1639131  12569.851770
# 16            Burkina Faso    Africa  2007   52.295  14326203   1217.032994
# 19                Cameroon    Africa  2007   50.430  17696293   2042.095240
# 22                    Chad    Africa  2007   50.651  10238807   1704.063724
# 26                 Comoros    Africa  2007   65.152    710960    986.147879
# 28             Congo, Rep.    Africa  2007   55.322   3800610   3632.557798
# 35                Djibouti    Africa  2007   54.791    496374   2082.481567
# 38                   Egypt    Africa  2007   71.338  80264543   5581.180998
# 40       Equatorial Guinea    Africa  2007   51.579    551201  12154.089750
# ...

# %% [markdown]
# ## What if you want to find countries where life exp is greater than 50 OR country is from Africa?

# %%
False or False # What is the 'or' command in pandas?
# Out:
# False

# %%
(df['lifeExp']>50)
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 137     True
# 138     True
# 139     True
# 140    False
# 141    False
# Name: lifeExp, Length: 142, dtype: bool

# %%
(df['continent']=='Africa')
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140     True
# 141     True
# Name: continent, Length: 142, dtype: bool

# %%
df[(df['continent']=='Africa') | (df['lifeExp']>50)]
# Out:
#                 country continent  year  lifeExp       pop     gdpPercap  \
# 1               Albania    Europe  2007   76.423   3600523   5937.029526
# 2               Algeria    Africa  2007   72.301  33333216   6223.367465
# 3                Angola    Africa  2007   42.731  12420476   4797.231267
# 4             Argentina  Americas  2007   75.320  40301927  12779.379640
# 5             Australia   Oceania  2007   81.235  20434176  34435.367440
# ..                  ...       ...   ...      ...       ...           ...
# 137             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 138  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 139         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 140              Zambia    Africa  2007   42.384  11746035   1271.211593
# 141            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#     iso_alpha  iso_num
# 1         ALB        8
# 2         DZA       12
# ...
